# %%
import pprint
import fitz
import re
from bs4 import BeautifulSoup

# %%
def extract_header_subheader_body(pdf_path):
    # Open the PDF file
    document = fitz.open(pdf_path)
    
    # List to store the text of the entire document
    full_text = []
    
    # Iterate through each page
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        text = page.get_text("text")
        full_text.append(text)
    
    # Join all pages' text into a single string
    full_text = "\n".join(full_text)
    
    # Convert the text into an HTML-like format
    html_text = ""
    for line in full_text.split("\n"):
        if re.match(r'^\d+\.\s', line):  # Numbered headers
            html_text += f"<h1>{line}</h1>\n"
        elif re.match(r'^\d+\.\d+\.\s', line):  # Numbered subheaders
            html_text += f"<h2>{line}</h2>\n"
        elif line.isupper():  # Assuming headers are in uppercase
            html_text += f"<h1>{line}</h1>\n"
        elif line.istitle():  # Assuming subheaders are in title case
            html_text += f"<h2>{line}</h2>\n"
        elif line.strip().startswith(("-", "*", "•")):  # Bullet lists
            html_text += f"<li>{line}</li>\n"
        else:
            html_text += f"<p>{line}</p>\n"
    
    # Parse the HTML-like text with BeautifulSoup
    soup = BeautifulSoup(html_text, "html.parser")
    
    # Extract headers, subheaders, and bodies
    content = []
    current_header = ""
    current_subheader = ""
    current_body = []
    
    for tag in soup.find_all(["h1", "h2", "p", "li"]):
        if tag.name == "h1":
            if current_header and current_body:
                content.append({
                    'header': current_header,
                    'subheader': current_subheader,
                    'body': "\n".join(current_body)
                })
                current_subheader = ""
                current_body = []
            current_header = tag.get_text()
        elif tag.name == "h2":
            if current_subheader and current_body:
                content.append({
                    'header': current_header,
                    'subheader': current_subheader,
                    'body': "\n".join(current_body)
                })
                current_body = []
            current_subheader = tag.get_text()
        else:
            current_body.append(tag.get_text())
    
    # Store the last section
    if current_header and current_body:
        content.append({
            'header': current_header,
            'subheader': current_subheader,
            'body': "\n".join(current_body)
        })
    
    return content

# %%
# Example usage
pdf_path = "ExampleRFPs/GoodFit/Attachment A - Statement of Work_July 2023.pdf"
content = extract_header_subheader_body(pdf_path)
pprint.pprint(content)
# Out:
# [{'body': 'Statement of Work ',
#   'header': '',
#   'subheader': 'Project Management Support '},
#  {'body': '1.', 'header': 'PR 777449 ', 'subheader': 'July 2023 '},
#  {'body': 'Battelle Memorial Institute, Pacific Northwest Division, operator '
#           'of the Pacific Northwest National \n'
#           'Laboratory (PNNL) for the U.S. Department of Energy is working '
#           'through a digital transformation \n'
#           'through critical strategic objectives against our operating model. ',
#   'header': 'OBJECTIVE/PURPOSE',
#   'subheader': ''},
#  {'body': 'PNNL has a portfolio of strategic initiatives to modernize various '
#           'business systems, and operating \n'
#           'model improvements initiatives for Assets & Facilities and '
#           'Operations. In support of these \n'
#           'needs, PNNL needs an agile project manager to successfully lead '
#           'these efforts through planning \n'
#           'and execution against strategic roadmaps. ',
#   'header': '2. BACKGROUND',
#   'subheader': ''},
#  {'body': '●\n'
#           'Under direction of Digital Platform Managers and the PMO Director, '
#           'lead initiatives\n'
#           'and manage over scope, schedule, and budget from planning through '
#           'execution.\n'
#           '●\n'
#           'Ensure the timely delivery of high-quality technical solutions that '
#           'drive key business\n'
#           'strategic outcomes.\n'
#           '●\n'
#           'Lead cross functional teams through all phases of the lifecycle, '
#           'from discovery to launch in\n'
#           'accordance with the PMO Playbook of standards, expectations, and '
#           'supporting tools.\n'
#           '●\n'
#           'Ensure appropriate resources are mobilized and delivery meets '
#           'outcomes.\n'
#           '●\n'
#           'Coach team members on delivering results.\n'
#           '●\n'
#           'Handling administrative tasks such as conducting meetings, '
#           'facilitating collaborations,\n'
#           'and eliminating barriers affecting progress.\n'
#           '●\n'
#           'Engage team members to ensure completion of follow-up items in a '
#           'timely fashion\n'
#           '●\n'
#           'Breakdown initial phase(s); make recommendations for tactical '
#           'actions and execution as\n'
#           'feasible\n'
#           '●\n'
#           'Engage business and technology teams to ensure a strong '
#           'understanding of practices\n'
#           'and requirements to safely maintain and track access within the '
#           'environment\n'
#           '●\n'
#           'Experience delivering work as a highly skilled individual '
#           'contributor\n'
#           '●\n'
#           'Strong customer focus: skilled ability to interpret and analyze '
#           'customer requirements.\n'
#           '●\n'
#           'Knowledge and experience with agile product and backlog management\n'
#           '●\n'
#           'Excellent presentation, communication skills and written '
#           'communication skills able to\n'
#           'speak with stakeholders of different levels\n'
#           '\n'
#           '●\n'
#           'Experience in the development of complex security systems using '
#           'industry best\n'
#           'practices\n'
#           '●\n'
#           'Exceptional communication with both technical and nontechnical '
#           'audiences\n'
#           '●\n'
#           'Demonstrated ability to think strategically to deliver innovative '
#           'solutions\n'
#           '●\n'
#           'Deliver results with highest level of professionalism and '
#           'integrity\n'
#           '●\n'
#           'Self-starter who brings solutions with a proactive, collaborative '
#           'approach',
#   'header': '3. WORK SCOPE',
#   'subheader': 'Required Skills: '},
#  {'body': 'Estimated Period of Performance (Date of Award/September 18, 2023 – '
#           'August 01, 2024) ',
#   'header': '4. SCHEDULE',
#   'subheader': ''},
#  {'body': 'In general, most of the work will be executed remotely. Periodic '
#           'onsite visits may be necessary \n'
#           'and will be coordinated between PNNL and the contractor. All travel '
#           'costs will be invoiced and \n'
#           'reimbursed by PNNL according to the GSA per diem rates. All travel '
#           'and housing arrangements \n'
#           'will be the responsibility of the contractor. ',
#   'header': '5. WORK LOCATION',
#   'subheader': ''},
#  {'body': 'The contractor will be required to successfully complete Cyber '
#           'Security training prior to arriving \n'
#           'at PNNL. This can be accomplished online through the PNNL Web '
#           'Portal.  The contractor will also \n'
#           'be enrolled in reading assignments to become familiar with the PMO '
#           'Portfolio Management Plan \n'
#           'and Playbook. ',
#   'header': '6. TRAINING',
#   'subheader': ''},
#  {'body': 'Deliverables for various initiatives will be defined dynamically '
#           'through the agile process to \n'
#           'prioritize work based on the outcomes. The contractor will be '
#           'accountable through status \n'
#           'reports, decision logs, and backlog grooming as prioritized by '
#           'PNNL. \n'
#           'PNNL will have ownership of and access to materials generated as '
#           'part of this engagement. \n'
#           'PNNL will provide guidance, standards, processes, and requirements '
#           'towards high quality \n'
#           'deliverables. ',
#   'header': '7. DELIVERABLES',
#   'subheader': ''},
#  {'body': 'The contractor must be strictly a United States Citizen (no dual '
#           'citizenship), living and working in \n'
#           'the United States and agree to protect controlled unclassified '
#           'information which will be \n'
#           'stipulated in the contract. ',
#   'header': '8. CITIZENSHIP',
#   'subheader': ''},
#  {'body': '\n'
#           'Contractor agrees to properly handle all Controlled Unclassified '
#           'Information (CUI) that \n'
#           'Contractor may have access to or generate under the performance of '
#           'this Contract. CUI may \n'
#           'include 1) Applied Technology Information; 2) Unclassified-Naval '
#           'Nuclear Propulsion \n'
#           'Information (U-NNPI); 3) Official Use Only Information (OUO); 4) '
#           'Personally Identifiable \n'
#           'Information (PII); 5) Unclassified Controlled Nuclear Information '
#           '(UCNI); 6) Battelle Business \n'
#           '(i.e., technology, technical data or sensitive nuclear technology) '
#           '9) other unclassified \n'
#           'information requiring special handling, e.g., For Official Use Only '
#           '(FOUO), Sensitive Security \n'
#           'Information (SSI), Confidential Foreign Government Information '
#           'Modified Handling Authorized \n'
#           '(C/FGI-MOD), and Safeguards Information (SGI); or 10) facts, data, '
#           'or knowledge for which the \n'
#           'disclosure, loss, misuse, alteration, or destruction could '
#           'adversely affect Battelle and Federal \n'
#           'government interests. Contractor is responsible to properly '
#           'identify, mark, protect, store, and \n'
#           'destroy all CUI in accordance with applicable Battelle, DOE, and '
#           'Federal agency policy. \n'
#           ' \n'
#           ' ',
#   'header': 'CONTROLLED UNCLASSIFIED INFORMATION (CUI)',
#   'subheader': 'Sensitive Information; 7) Battelle Strictly Private '
#                'Information; 8) Export Controlled Information '},
#  {'body': ' \nCosts consist of the following: \n ',
#   'header': '10. Service Fees ',
#   'subheader': 'Role'},
#  {'body': '2000 hours \n'
#           ' \n'
#           'Fees will be billed monthly based on actual usage. Anticipated '
#           'Period of Performance dates – \n'
#           'TBD Date of Award/ August 1, 2023, through January 31, 2024. \n',
#   'header': '10. Service Fees ',
#   'subheader': 'Manager '}]
